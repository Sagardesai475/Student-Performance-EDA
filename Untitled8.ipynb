# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot  as plt
# %matplotlib inline
import warnings

# %%
#IMPORTING DATASET
df = pd.read_csv("C:/Users/SAGAR/Desktop/StudentsPerformance.csv")

# %%
#TOP 5 DATSTET
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#SHAPE OF DATASET 
df.shape
# Out:
# (1000, 8)

# %%
#DATA CHECKS TO PERFORM

# %%
#CHECKING THE MISSING VALUE 
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
#CHECKING THE DUPLICATES
df. duplicated().sum()
# Out:
# 0

# %%
#CHECKING NULL AND DATATYPES
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
#checking number of unique value of each column 
df.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
# From above table we can see
1) Means of all the scores are closer to each other 
2) All the Standard deviation scores are closer to each other which indicates it has similar central tendency and spread

# %%
#DATA EXPLORATION 
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
print("Categories in 'Gender' variable :    ", end = " ")
print (df['gender'].unique())

print("Categories in 'Race/ Ethinicity' variable :    ", end = "  ")
print(df['race/ethnicity'].unique())

print ("Categories in 'Parental level of education' variable :    ", end = "  " )
print(df['parental level of education'].unique())

print ("Categories in 'lunch' variable :    ", end = "  " )
print(df['lunch'].unique())

print ("Categories in 'test preparation course' variable :    ", end = "  " )
print(df['test preparation course'].unique())
# Out:
# Categories in 'Gender' variable :     ['female' 'male']
# Categories in 'Race/ Ethinicity' variable :      ['group B' 'group C' 'group A' 'group D' 'group E']
# Categories in 'Parental level of education' variable :      ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# Categories in 'lunch' variable :      ['standard' 'free/reduced']
# Categories in 'test preparation course' variable :      ['none' 'completed']

# %%
#define numerical and categorical column
numerical_features = [a for a in df.columns if df[a].dtypes != 'O']
categorical_features = [a for a in df.columns if df[a].dtypes == 'O']

print("We have {} columns in numerical_features : {}".format(len(numerical_features), numerical_features))
print("We have {} columns in categorical_features : {}".format(len(categorical_features), categorical_features))
# Out:
# We have 3 columns in numerical_features : ['math score', 'reading score', 'writing score']
# We have 5 columns in categorical_features : ['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course']

# %%
#adding column for total score and average
df['Total_score'] = df['math score'] + df['reading score'] + df['writing score']
df['average'] = df['Total_score']/2
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Total_score  average
# 0          218    109.0
# 1          247    123.5
# 2          278    139.0
# 3          148     74.0
# 4          229    114.5

# %%
reading_full = df[df['reading score'] == 100]['reading score'].count()
writing_full = df[df['writing score'] == 100]['writing score'].count()
math_full = df[df['math score'] == 100]['math score'].count()


print (f'no. of student getting full mark in reading: {reading_full}')
print (f'no. of student getting full mark in reading: {writing_full}')
print (f'no. of student getting full mark in reading: {math_full}')
# Out:
# no. of student getting full mark in reading: 17
# no. of student getting full mark in reading: 14
# no. of student getting full mark in reading: 7

# %%
read_score_less20 = df[df['reading score']<= 20]['reading score'].count()
write_score_less20 = df[df['writing score']<= 20]['writing score'].count()
math_score_less20 = df[df['math score']<= 20]['math score'].count()


print("no of student score is less than 20 in reading: {}".format(read_score_less20))
print(f'no. of student score is  less than 20 in writing : {write_score_less20}')
print(f'no of student score is less than 20 in math: {math_score_less20}')
# Out:
# no of student score is less than 20 in reading: 1
# no. of student score is  less than 20 in writing : 3
# no of student score is less than 20 in math: 4

# %%
#FROM ABOVE CODE WE CAN SEE -
1) Students are performing worst in Maths
2) best performance is seen in reading as 17 students have scored 100 marks

# %%
#DATA VISUALIZATION
fig, axs = plt.subplots(1,2, figsize = (15,7))
plt.subplot(121)
sns.histplot(data = df, x= 'average', bins = 30, color = 'g', kde = True)
plt.subplot(122)
sns.histplot(data = df, x='average', bins = 30 , color = 'g', kde = True, hue = 'gender')
# Out:
# <Axes: xlabel='average', ylabel='Count'>

# %%
#Inisghts - 
1) Female students performs better than male students

# %%
fig, axs = plt.subplots(1,2, figsize = (15,8))
plt.subplot(121)
sns.histplot(data = df, x= 'Total_score', bins = 30 , kde = True, color = 'g')
plt.subplot(122)
sns.histplot(data = df , x= 'Total_score', bins = 30 , kde = True,color = 'g', hue = 'gender')
# Out:
# <Axes: xlabel='Total_score', ylabel='Count'>

# %%
# TO SEE THE PERFORMANC EOF STUDENT AS PER LUNCH AS PER GENDER CATEGORY
fid, axs = plt.subplots(1,3, figsize = (15,5))
plt.subplot(131)
sns.histplot(data = df, x = 'average', kde = True, color = 'g', hue = 'lunch')
plt.subplot(132)
sns.histplot(data= df[df.gender == 'female'], x ='average', kde = True , color = 'g', hue = 'lunch')
plt.subplot(133)
sns.histplot(data = df[df.gender == 'male'], x= 'average', kde  = 'True', color = 'g', hue = 'lunch' )
# Out:
# <Axes: xlabel='average', ylabel='Count'>

# %%
#INSIGHTS 
1) Students who receive standard lunch tend to perform better in exams across both gender categories, including males and females.

# %%
#To know the perfomance of student based on the parental level of education as per gender category 
fig, axs = plt.subplots(1,3,figsize = (17,7))

plt.subplot(131)
sns.histplot(data = df, x= 'average', kde = True, color = 'g', hue = 'parental level of education')

plt.subplot(132)
sns.histplot (data = df[df.gender == 'male'],x = 'average', kde = True,color = 'g', hue = 'parental level of education')

plt.subplot(133)
sns.histplot(data = df[df.gender == 'female'], x= 'average',kde = True, color = 'g', hue  = 'parental level of education')
# Out:
# <Axes: xlabel='average', ylabel='Count'>

# %%
#INSIGHTS - 
1) In general parents education dont help student perform well in exam.
2) 2nd plot shows that parents whose education is of associates degree or masters degree their male child tend to perform well in exam
3) 3rd plot we can see there is no effect of parents education on female students.

# %%
#To know the perfomance of student based on the Race / ethinicity as per gender category 
plt.subplots(1,3,figsize=(25,5))
plt.subplot(141)
ax =sns.histplot(data=df,x='average',kde=True,hue='race/ethnicity')
plt.subplot(142)
ax =sns.histplot(data=df[df.gender=='female'],x='average',kde=True,hue='race/ethnicity')
plt.subplot(143)
ax =sns.histplot(data=df[df.gender=='male'],x='average',kde=True,hue='race/ethnicity')

# %%
#Insights 
1) Students of group A and group B tends to perform poorly in exam.
2) Students of group A and group B tends to perform poorly in exam irrespective of whether they are male or female

# %%
# distribution of students scores across different subjects
fig, axs = plt.subplots(1,3, figsize= (15,9))
plt.subplot(131)
plt.title('MATH SCORES')
sns.violinplot(y='math score',data=df,color='red',linewidth=3)
plt.subplot(132)
plt.title('READING SCORES')
sns.violinplot(y='reading score',data=df,color='green',linewidth=3)
plt.subplot(133)
plt.title('WRITING SCORES')
sns.violinplot(y='writing score',data=df,color='blue',linewidth=3)
# Out:
# <Axes: title={'center': 'WRITING SCORES'}, ylabel='writing score'>

# %%
#Insights 
1) From the above three plots its clearly visible that most of the students score in between 
60-80 in Maths whereas in reading and writing most of them score from 50-80

# %%
# Multivariate analysis using pieplot
fig, axs = plt.subplots(1,5, figsize = (25,7))
plt.subplot(151)
size = df['gender'].value_counts()
label = df['gender'].unique()
color = ['blue', 'pink']

plt.pie(size, colors = color, labels = label, autopct = '%.2f%%' )
plt.title = 'Gender'

plt.subplot(152)
size = df['race/ethnicity'].value_counts()
label = df['race/ethnicity'].unique()
color = ['blue', 'pink']
plt.pie(size, labels = label, colors = color , autopct = '%.2f%%')
plt.title = 'race/ethnicity'

plt.subplot(153)
size = df['lunch'].value_counts()
label = df['lunch'].unique()
color = ['blue', 'pink']
plt.pie(size, labels = label, colors = color , autopct = '%.2f%%')
plt.title= 'lunch'

plt.subplot(154)
size = df['parental level of education'].value_counts()
label = df['parental level of education'].unique()
color = ['blue', 'pink']
plt.pie(size, labels = label, colors = color , autopct = '%.2f%%')
plt.title= 'parental level of education'

plt.subplot(155)
size = df['test preparation course'].value_counts()
label = df['test preparation course'].unique()
color = ['blue', 'pink']
plt.pie(size, labels = label, colors = color , autopct = '%.2f%%')
plt.title= 'test preparation course'

# %%
#INSIGHTS 
1) Number of Male and Female students is almost equal
2) Number students are greatest in Group B
3) Number of students who have standard lunch are greater
4) Number of students who have not enrolled in any test preparation course is greater
5) Number of students whose parental education is Some College is greater followed closely by Bachelors Degree

# %%
#UNIVARIATE ANALYSIS
f,ax=plt.subplots(1,2,figsize=(20,10))
sns.countplot(x=df['gender'],data=df,palette ='bright',ax=ax[0],saturation=0.95)
for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=20)
    
plt.pie(x=df['gender'].value_counts(),labels=df['gender'].value_counts().index,explode=[0,0.1],autopct='%1.1f%%',shadow=True,colors=['#ff4d4d','#ff8000'])
plt.show()

# %%
#INSIGHTS -
Gender has balanced data with female students are 518 (48%) and male students are 482 (52%)

# %%
# Filter to include only numeric columns
gender_group = df.groupby('gender').mean(numeric_only=True)
gender_group
# Out:
#         math score  reading score  writing score  Total_score     average
# gender
# female   63.633205      72.608108      72.467181   208.708494  104.354247
# male     68.728216      65.473029      63.311203   197.512448   98.756224

# %%
plt.figure(figsize=(10, 8))

X = ['Total Average','Math Average']


female_scores = [gender_group['average'][0], gender_group['math score'][0]]
male_scores = [gender_group['average'][1], gender_group['math score'][1]]

X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, male_scores, 0.4, label = 'Male')
plt.bar(X_axis + 0.2, female_scores, 0.4, label = 'Female')
  
plt.xticks(X_axis, X)
plt.ylabel("Marks")

plt.legend()

# %%
#Inisghts 
1) On an average females have a better overall score than men.
2) whereas males have scored higher in Maths.

# %%
#UNIVARIATE ANALYSIS FOR THE GROUP WISE DISTRIBUTION - 
f,ax=plt.subplots(1,2,figsize=(20,10))
sns.countplot(data = df, x = df['race/ethnicity'],ax=ax[0])
for a in ax[0].containers:
    ax[0].bar_label(a, color='black', size=20)


plt.pie(x=df['race/ethnicity'].value_counts(), labels = df['race/ethnicity'].unique(),explode = [0, 0.1,0.1,0.1,0.1],autopct='%1.1f%%',shadow=True,colors=['#ff4d4d','#ff8000'])
# Out:
# ([<matplotlib.patches.Wedge at 0x2ba489af310>,
# ...
#  [Text(0.592324332246979, 0.9269044640242977, 'group B'),
#   Text(-1.1412678264979264, 0.3708203718792959, 'group C'),
#   Text(-0.5380598657352365, -1.0726097057574016, 'group A'),
#   Text(0.6493454908364958, -1.009133506296521, 'group D'),
#   Text(1.1533985045343034, -0.33116746479392106, 'group E')],
#  [Text(0.3230859994074431, 0.5055842531041623, '31.9%'),
#   Text(-0.6657395654571236, 0.21631188359625594, '26.2%'),
#   Text(-0.31386825501222126, -0.6256889950251507, '19.0%'),
#   Text(0.37878486965462255, -0.5886612120063038, '14.0%'),
#   Text(0.6728157943116768, -0.19318102112978724, '8.9%')])

# %%
#INSIGHTS 
1) Most of the student belonging from group C /group D.
2) Lowest number of students belong to groupA.

# %%
#BIVARIATE ANALYSIS ( Is Race/Ehnicity has any impact on student's performance ? )
race_group = df.groupby('race/ethnicity')
race_group
f, ax = plt.subplots(1, 3, figsize=(20, 8))
sns.barplot(x= race_group['math score'].mean().index, y =  race_group ['math score'].mean().values, ax=ax[0])
ax[0].set_title('Math score',color='#005ce6',size=20)

for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=15)

sns.barplot(x = race_group['reading score'].mean().index, y = race_group['reading score'].mean().values, ax=ax[1])
ax[1].set_title('Reading Score', size=20)

for container in ax[1].containers:
    ax[1].bar_label(container,size = 15)

sns.barplot(x=Group_data2['writing score'].mean().index,y=Group_data2['writing score'].mean().values,palette = 'coolwarm',ax=ax[2])
ax[2].set_title('Writing score',color='#005ce6',size=20)

for container in ax[2].containers:
    ax[2].bar_label(container,color='black',size=15)

# %%
#INSIGHTS - 
1) Group E students have scored the highest marks in all three format.
2) Group A students have scored the lowest marks.
3) Students from a lower Socioeconomic status have a lower avg in all course subjects

# %%
#univariate analysis according to the parental level of education 
fig, axs = plt.subplots(figsize = (15,5))
df['parental level of education'] = df['parental level of education'].astype('category')
sns.countplot(data=df, x='parental level of education', palette='Greens', ax=axs)

for a in axs.containers:
    axs.bar_label(a, size = 15)
plt.title = 'Count of Parental Level of Education'
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, "associate's degree"),
#   Text(1, 0, "bachelor's degree"),
#   Text(2, 0, 'high school'),
#   Text(3, 0, "master's degree"),
#   Text(4, 0, 'some college'),
#   Text(5, 0, 'some high school')])

# %%
#Insights
1) Largest number of parents are from some college followed by associates degree

# %%
#BIVARIATE ANALYSIS ( Is parental education has any impact on student's performance ? )

# %%
numeric_cols = df.select_dtypes(include='number').columns

group_data = df.groupby('parental level of education')[numeric_cols].mean()
 group_data.plot(kind= 'barh', figsize = (10,10) )

plt.legend(bbox_to_anchor = (1.20,1), loc = 'upper right')
# Out:
#   Cell In[455], line 4
#     group_data.plot(kind= 'barh', figsize = (10,10) )
#     ^
# IndentationError: unexpected indent

# %%
#INSIGHTS 
The score of student whose parents possess master and bachelor level education are higher than others.

# %%
#UNIVARIATE ANALYSIS ( Which type of lunch is most common amoung students ? )
fig,ax = plt.subplots(figsize = (10,5))
df['lunch'] = df['lunch'].astype('category')
sns.countplot(data = df, x= 'lunch', palette = 'PuBu')
for a in ax.containers:
    ax.bar_label(a)

plt.xlabel('types of lunch')
plt.ylabel('count')
plt.show()

# %%
#Inisghts 
Students being served Standard lunch was more than free lunch

# %%
#BIVARIATE ANALYSIS ( Is lunch type intake has any impact on student's performance ? )

f,ax=plt.subplots(1,2,figsize=(20,8))
sns.countplot(x=df['parental level of education'],data=df,palette = 'bright',hue='test preparation course',saturation=0.95,ax=ax[0])
ax[0].set_title('Students vs test preparation course ',color='black',size=25)
for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=20)
    
sns.countplot(x=df['parental level of education'],data=df,palette = 'bright',hue='lunch',saturation=0.95,ax=ax[1])
for container in ax[1].containers:
    ax[1].bar_label(container,color='black',size=20)

# %%
#INSIGHTS -- 

1) Students who get Standard Lunch tend to perform better than students who got free/reduced lunch

# %%
#BIVARIATE ANALYSIS ( Is Test prepration course has any impact on student's performance ? )
plt.figure(figsize=(12,6))
plt.subplot(2,2,1)
sns.barplot (x=df['lunch'], y=df['math score'], hue=df['test preparation course'])
plt.subplot(2,2,2)
sns.barplot (x=df['lunch'], y=df['reading score'], hue=df['test preparation course'])
plt.subplot(2,2,3)
sns.barplot (x=df['lunch'], y=df['writing score'], hue=df['test preparation course'])
# Out:
# <Axes: xlabel='lunch', ylabel='writing score'>

# %%
#Insights
Students who have completed the Test Prepration Course have scores higher in all three categories than those who haven't taken the course

# %%
#Checking the outliers
plt.subplots(1,4,figsize=(16,5))
plt.subplot(141)
sns.boxplot(df['math score'],color='skyblue')

plt.subplot(142)
sns.boxplot(df['reading score'],color='hotpink')
plt.subplot(143)
sns.boxplot(df['writing score'],color='yellow')
plt.subplot(144)
sns.boxplot(df['average'],color='lightgreen')
plt.show()

# %%
#Multiuvariate analysis usin pairplot 
sns.pairplot(df,hue = 'gender')
plt.show()

# %%
#Insights 
From the above plot it is clear that all the scores increase linearly with each other

# %%
# Conclusions
1) Student's Performance is related with lunch, race, parental level education
2) Females lead in pass percentage and also are top-scorers
3) Student's Performance is not much related with test preparation course
4) Finishing preparation course is benefitial.
